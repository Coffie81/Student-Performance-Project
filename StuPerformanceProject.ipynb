# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("student_performance_100 2.csv")


#Hardest score
subject_avgs = df[['math_score', 'reading_score', 'writing_score']].mean()
print(subject_avgs)

hardest_subject = subject_avgs.idxmin()
hardest_score = subject_avgs.min()

print("Hardest Subject:", hardest_subject, " with Average Score:", hardest_score)
# Out:
# math_score       63.81
# reading_score    64.54
# writing_score    69.69
# dtype: float64
# Hardest Subject: math_score  with Average Score: 63.81

# %%
# Out:
#     student_id  gender  math_score  reading_score  writing_score  \
# 0            1    Male          92             36             78
# 1            2  Female          47             36             85
# 2            3    Male          73             88             92
# 3            4    Male          63             35             95
# 4            5    Male          91             53             64
# ..         ...     ...         ...            ...            ...
# 95          96  Female          68             64             48
# 96          97  Female          31             80             83
# 97          98  Female          32             40             89
# 98          99  Female          85             71             61
# 99         100    Male          88             58             79
#
#     attendance_percent
# 0                   89
# 1                   64
# 2                   71
# 3                   75
# 4                   85
# ..                 ...
# 95                  78
# 96                  71
# 97                  68
# 98                  66
# 99                  87
#
# [100 rows x 6 columns]

# %%
#The 5 top performing Students
df['average_score'] = df[['math_score', 'reading_score', 'writing_score']].mean(axis=1)

top_students = df.sort_values(by='average_score', ascending=False).head(5)
print(top_students[['gender','student_id', 'average_score']])
# Out:
#     gender  student_id  average_score
# 91  Female          92      94.666667
# 78    Male          79      91.000000
# 17  Female          18      88.333333
# 6     Male           7      87.666667
# 10    Male          11      87.000000

# %%
#Comparing Performance by Gender
gender_comparison = df.groupby('gender')[['math_score', 'reading_score', 'writing_score']].mean()
print(gender_comparison)
# Out:
#         math_score  reading_score  writing_score
# gender
# Female   59.285714      62.446429      72.232143
# Male     69.568182      67.204545      66.454545

# %%
#Visualization (Showing the Average Scores for each subject)
plt.figure()
subject_avgs.plot(kind='bar')
plt.title("Average Score per Subject")
plt.xlabel("Subject")
plt.ylabel("Average Score")
plt.show()

# %%
#Visualization(Gender Performance)
plt.figure() 
gender_comparison.plot(kind='bar')
plt.title("Average Scores by Gender")
plt.xlabel("Gender")
plt.ylabel("Average Score")
plt.show()

# %%
#Mathematics has the lowest average score, making it the hardest subject.

#Insight 2:

#Female students perform better in Writing, while male students perform better in Math and Reading.

 #Insight 3:

#Top-performing students score highly across all subjects, not just one

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined
